# %%
# !pip install pycaret

# %%
try:
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    from pycaret.datasets import get_data
    # from pycaret.utils import version
    print('all modules imported successfully')
except Exception as e:
    print(e)
    exit()
# Out:
# all modules imported successfully

# %%
dataset = get_data('index')
dataset
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *
s = setup(data=data,target="charges",train_size=0.7)
# Out:
# <style type="text/css">
# #T_bf8a7_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bf8a7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf8a7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bf8a7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf8a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf8a7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bf8a7_row0_col1" class="data row0 col1" >7880</td>
#     </tr>
#     <tr>
#       <th id="T_bf8a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf8a7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bf8a7_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_bf8a7_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm = compare_models()
# Out:
# <style type="text/css">
# #T_2ace6 th {
#   text-align: left;
# }
# ...

# %%
model = create_model('gbr')
# Out:
# <style type="text/css">
# #T_29e13_row10_col0, #T_29e13_row10_col1, #T_29e13_row10_col2, #T_29e13_row10_col3, #T_29e13_row10_col4, #T_29e13_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_29e13" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29e13_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_29e13_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_29e13_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_29e13_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_29e13_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_29e13_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
sm = save_model(model,'insurance_model')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
load_model1 = load_model('/content/insurance_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
from pycaret.regression import *
s = setup(data=data,target="charges")
cm = compare_models()
model = create_model('gbr')
# Out:
# <style type="text/css">
# #T_16ded_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_16ded" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16ded_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_16ded_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16ded_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16ded_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_16ded_row0_col1" class="data row0 col1" >6659</td>
#     </tr>
#     <tr>
#       <th id="T_16ded_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16ded_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_16ded_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_16ded_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
sm = save_model(model,'insurance_model_full')
load_model1 = load_model('/content/insurance_model_full')
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded

# %%
data_dict = {'age':40,"sex":1,"bmi":40.30,"children":4,"smoker":1,"region":2}
df = pd.DataFrame(data_dict,index=[0])
df
# Out:
#    age  sex   bmi  children  smoker  region
# 0   40    1  40.3         4       1       2

# %%
from scipy.stats import mode
pred = predict_model(model,df)

# %%
pred
# Out:
#    age  sex        bmi  children  smoker  region  prediction_label
# 0   40    1  40.299999         4       1       2      10350.332221
